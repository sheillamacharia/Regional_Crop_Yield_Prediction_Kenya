# %%
import pandas as pd

# %%
# Reading the data
Kenya_Crops = pd.read_csv('..\data\kenya_crops_only.csv', encoding='latin-1')
Kenya_Crops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3658 entries, 0 to 3657
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               3658 non-null   int64
#  1   Item               3658 non-null   object
#  2   Item Code (CPC)    3658 non-null   float64
#  3   Area_Harvested_ha  3377 non-null   float64
#  4   Production_tonnes  3658 non-null   float64
#  5   Yield_hg_per_ha    3317 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 171.6+ KB

# %%
Kenya_Crops.head()
# Out:
#    Year        Item  Item Code (CPC)  Area_Harvested_ha  Production_tonnes  \
# 0  1961    Apricots           1343.0                2.0               10.0
# 1  1961    Avocados           1311.0             1100.0            16000.0
# 2  1961     Bananas           1312.0            40000.0           400000.0
# 3  1961      Barley            115.0            12666.0            13513.0
# 4  1961  Beans, dry           1701.0           115000.0            55000.0
#
#    Yield_hg_per_ha
# 0          50000.0
# 1         145455.0
# 2         100000.0
# 3          10669.0
# 4           4783.0

# %%
Pesticides_df = pd.read_csv('..\data\environment_pesticides_e_all_data.csv', sep=';', encoding='utf-8-sig')
Pesticides_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100004 entries, 0 to 100003
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Year             100004 non-null  int64
#  1   Area             100004 non-null  object
#  2   Item             100004 non-null  object
#  3   Element          100004 non-null  object
#  4   Value            100004 non-null  float64
#  5   Unit             100004 non-null  object
#  6   Area Code (M49)  99674 non-null   object
#  7   Note             100004 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.1+ MB

# %%
Pesticides_df.head()
# Out:
#    Year                                               Area  \
# 0  2005  United Kingdom of Great Britain and Northern I...
# 1  2012  United Kingdom of Great Britain and Northern I...
# 2  2021  United Kingdom of Great Britain and Northern I...
# 3  1993  United Kingdom of Great Britain and Northern I...
# 4  2002  United Kingdom of Great Britain and Northern I...
#
#                  Item                   Element  Value    Unit  \
# 0  Pesticides (total)  Use per area of cropland   5.44   kg/ha
# 1  Pesticides (total)  Use per area of cropland   2.83   kg/ha
# 2  Pesticides (total)  Use per area of cropland   2.44   kg/ha
# 3  Pesticides (total)            Use per capita   0.56  kg/cap
# 4  Pesticides (total)            Use per capita   0.52  kg/cap
#
#   Area Code (M49)             Note
# 0       826-01-01  Estimated Value
# 1       826-01-01  Estimated Value
# 2       826-01-01  Estimated Value
# 3       826-01-01  Estimated Value
# 4       826-01-01  Estimated Value

# %%
Region_Yield = pd.read_csv(r'..\data\adm_crop_production_KE.csv')
Region_Yield.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43758 entries, 0 to 43757
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              43758 non-null  int64
#  1   fnid                    43758 non-null  object
#  2   country                 43758 non-null  object
#  3   country_code            43758 non-null  object
#  4   admin_1                 43758 non-null  object
#  5   admin_2                 43758 non-null  object
#  6   name                    43758 non-null  object
#  7   product                 43758 non-null  object
#  8   season_name             43758 non-null  object
#  9   planting_year           43758 non-null  int64
#  10  planting_month          43758 non-null  int64
#  11  harvest_year            43758 non-null  int64
#  12  harvest_month           43758 non-null  int64
#  13  crop_production_system  43758 non-null  object
#  14  indicator               43758 non-null  object
#  15  value                   43758 non-null  float64
# dtypes: float64(1), int64(5), object(10)
# memory usage: 5.3+ MB

# %%
Region_Yield.head(10)
# Out:
#    Unnamed: 0        fnid country country_code  admin_1 admin_2     name  \
# 0           0  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 1           1  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 2           2  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 3           3  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 4           4  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 5           5  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 6           6  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 7           7  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 8           8  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 9           9  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
#
#               product season_name  planting_year  planting_month  \
# 0                Kale      Annual           2022               1
# 1          Watermelon      Annual           2022               1
# 2              Banana      Annual           2012               1
# 3              Banana      Annual           2013               1
# 4              Banana      Annual           2022               1
# 5  Coconut (in shell)      Annual           2012               1
# 6  Coconut (in shell)      Annual           2013               1
# 7  Coconut (in shell)      Annual           2014               1
# 8  Coconut (in shell)      Annual           2015               1
# 9  Coconut (in shell)      Annual           2016               1
#
#    harvest_year  harvest_month crop_production_system indicator   value
# 0          2022             12               All (PS)      area    21.0
# 1          2022             12               All (PS)      area    26.0
# 2          2012             12               All (PS)      area   125.1
# 3          2013             12               All (PS)      area   121.5
# 4          2022             12               All (PS)      area    39.0
# 5          2012             12               All (PS)      area  6165.0
# 6          2013             12               All (PS)      area  6165.0
# 7          2014             12               All (PS)      area   100.0
# 8          2015             12               All (PS)      area   159.0
# 9          2016             12               All (PS)      area   168.0

# %%
Region_Yield['season_name'].unique()
# Out:
# array(['Annual', 'Long', 'Short'], dtype=object)

# %%
# Unique names in the product column in asending order
Crops_Regional_Yield = Region_Yield['product'].value_counts().index.sort_values(ascending=True)
Crops_Regional_Yield
# Out:
# Index(['Amaranth', 'Arrowroot', 'Bambara groundnut', 'Banana', 'Barley',
#        'Beans (mixed)', 'Black nightshade', 'Cabbage', 'Canola Seed',
#        'Carrots', 'Cashew (unshelled)', 'Cassava', 'Coconut (in shell)',
#        'Coffee', 'Coriander', 'Cotton', 'Cowpea', 'Groundnuts (In Shell)',
#        'Jute', 'Kale', 'Macadamia', 'Maize', 'Millet', 'Mung bean', 'Onions',
#        'Pea', 'Pigeon Pea', 'Pineapple', 'Potato', 'Pyrethrum', 'Rice',
#        'Scallion', 'Sesame Seed', 'Sorghum', 'Sugarcane', 'Sunflower Seed',
#        'Sweet Potatoes', 'Taro', 'Tea', 'Tobacco', 'Tomato', 'Watermelon',
#        'Wheat', 'Yams'],
#       dtype='object', name='product')

# %%
Crops_Item = Kenya_Crops['Item'].value_counts().index.sort_values(ascending=True)
Crops_Item
# Out:
# Index(['Apples', 'Apricots', 'Artichokes', 'Asparagus', 'Avocados', 'Bananas',
#        'Barley', 'Beans, dry', 'Beer of barley, malted',
#        'Broad beans and horse beans, green', 'Cabbages', 'Carrots and turnips',
#        'Cashew nuts, in shell', 'Cassava, fresh', 'Castor oil seeds',
#        'Chestnuts, in shell', 'Chick peas, dry',
#        'Chillies and peppers, dry (Capsicum spp., Pimenta spp.), raw',
#        'Chillies and peppers, green (Capsicum spp. and Pimenta spp.)',
#        'Cloves (whole stems), raw', 'Coconuts, in shell', 'Coffee, green',
#        'Cotton lint, ginned', 'Cotton seed', 'Cottonseed oil', 'Cow peas, dry',
#        'Cucumbers and gherkins', 'Dates', 'Ginger, raw', 'Green garlic',
#        'Green tea (not fermented), black tea (fermented) and partly fermented tea',
#        'Groundnuts, excluding shelled',
#        'Leeks and other alliaceous vegetables', 'Lemons and limes',
#        'Lentils, dry', 'Lettuce and chicory', 'Linseed', 'Maize (corn)',
#        'Mangoes, guavas and mangosteens', 'Millet', 'Mushrooms and truffles',
#        'Nutmeg, mace, cardamoms, raw', 'Oats',
#        'Onions and shallots, dry (excluding dehydrated)', 'Oranges', 'Papayas',
#        'Peaches and nectarines', 'Pears', 'Peas, green',
#        'Pepper (Piper spp.), raw', 'Pigeon peas, dry', 'Pineapples',
#        'Plantains and cooking bananas', 'Plums and sloes',
#        'Pomelos and grapefruits', 'Potatoes', 'Pyrethrum, dried flowers',
#        'Rice', 'Seed cotton, unginned', 'Sesame seed', 'Sorghum', 'Soya beans',
#        'Spinach', 'Strawberries', 'Sugar cane', 'Sunflower seed',
#        'Sweet potatoes', 'Tangerines, mandarins, clementines', 'Tea leaves',
#        'Tomatoes', 'Unmanufactured tobacco', 'Vanilla, raw', 'Watermelons',
#        'Wheat', 'Yams'],
#       dtype='object', name='Item')

# %%
Temp_df = pd.read_csv('..\data\kenya-climate-data-1991-2016-temp-degress-celcius.csv')
Temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312 entries, 0 to 311
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     312 non-null    int64
#  1   Month Average            312 non-null    object
#  2   Temperature - (Celsius)  312 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 7.4+ KB

# %%
Rainfall_df = pd.read_csv('..\data\kenya-climate-data-1991-2016-rainfallmm.csv')
Rainfall_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312 entries, 0 to 311
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             312 non-null    int64
#  1   Month Average    312 non-null    object
#  2   Rainfall - (MM)  312 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 7.4+ KB

# %%
# Extracting the Kenyan data from pesticides dataset
Kenyan_data = Pesticides_df[Pesticides_df['Area'] == 'Kenya']
Kenyan_data.head(20)
# Out:
#       Year   Area                Item  \
# 4927  1999  Kenya  Pesticides (total)
# 4928  2002  Kenya  Pesticides (total)
# 4929  2006  Kenya  Pesticides (total)
# 4930  2008  Kenya  Pesticides (total)
# 4931  2014  Kenya  Pesticides (total)
# 4932  1992  Kenya  Pesticides (total)
# 4933  1999  Kenya  Pesticides (total)
# 4934  2003  Kenya  Pesticides (total)
# 4935  2021  Kenya  Pesticides (total)
# 4936  1992  Kenya  Pesticides (total)
# 4937  2000  Kenya  Pesticides (total)
# 4938  2011  Kenya  Pesticides (total)
# 4939  2016  Kenya  Pesticides (total)
# 4940  2020  Kenya  Pesticides (total)
# 4941  2021  Kenya  Pesticides (total)
# 4942  2022  Kenya  Pesticides (total)
# 4943  1990  Kenya  Pesticides (total)
# 4944  1999  Kenya  Pesticides (total)
# 4945  2002  Kenya  Pesticides (total)
# 4946  2003  Kenya  Pesticides (total)
#
#                                        Element    Value    Unit  \
# 4927                          Agricultural Use  2124.00       t
# 4928                          Agricultural Use  1665.40       t
# 4929                          Agricultural Use  2192.58       t
# 4930                          Agricultural Use  2157.53       t
# 4931                          Agricultural Use  4660.68       t
# 4932                  Use per area of cropland     0.23   kg/ha
# 4933                  Use per area of cropland     0.38   kg/ha
# 4934                  Use per area of cropland     0.31   kg/ha
# 4935                  Use per area of cropland     0.76   kg/ha
# 4936                            Use per capita     0.05  kg/cap
# 4937                            Use per capita     0.06  kg/cap
# 4938                            Use per capita     0.07  kg/cap
# 4939                            Use per capita     0.10  kg/cap
# 4940                            Use per capita     0.12  kg/cap
# 4941                            Use per capita     0.10  kg/cap
# 4942                            Use per capita     0.09  kg/cap
# 4943  Use per value of agricultural production     0.07  g/Int$
# 4944  Use per value of agricultural production     0.24  g/Int$
# 4945  Use per value of agricultural production     0.18  g/Int$
# 4946  Use per value of agricultural production     0.18  g/Int$
#
#      Area Code (M49)                       Note
# 4927       404-01-01  Estimated using net trade
# 4928       404-01-01  Estimated using net trade
# 4929       404-01-01  Estimated using net trade
# 4930       404-01-01  Estimated using net trade
# 4931       404-01-01  Estimated using net trade
# 4932       404-01-01            Estimated Value
# 4933       404-01-01            Estimated Value
# 4934       404-01-01            Estimated Value
# 4935       404-01-01            Estimated Value
# 4936       404-01-01            Estimated Value
# 4937       404-01-01            Estimated Value
# 4938       404-01-01            Estimated Value
# 4939       404-01-01            Estimated Value
# 4940       404-01-01            Estimated Value
# 4941       404-01-01            Estimated Value
# 4942       404-01-01            Estimated Value
# 4943       404-01-01            Estimated Value
# 4944       404-01-01            Estimated Value
# 4945       404-01-01            Estimated Value
# 4946       404-01-01            Estimated Value

# %%
Kenyan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 264 entries, 4927 to 83709
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             264 non-null    int64
#  1   Area             264 non-null    object
#  2   Item             264 non-null    object
#  3   Element          264 non-null    object
#  4   Value            264 non-null    float64
#  5   Unit             264 non-null    object
#  6   Area Code (M49)  264 non-null    object
#  7   Note             264 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 18.6+ KB

# %%
# Cleaning the Kenya_Crops dataset
Kenya_Crops.head(10)
# Out:
#    Year                                               Item  Item Code (CPC)  \
# 0  1961                                           Apricots          1343.00
# 1  1961                                           Avocados          1311.00
# 2  1961                                            Bananas          1312.00
# 3  1961                                             Barley           115.00
# 4  1961                                         Beans, dry          1701.00
# 5  1961                             Beer of barley, malted         24310.01
# 6  1961                              Cashew nuts, in shell          1372.00
# 7  1961                                     Cassava, fresh          1520.01
# 8  1961                                   Castor oil seeds          1447.00
# 9  1961  Chillies and peppers, dry (Capsicum spp., Pime...          1652.00
#
#    Area_Harvested_ha  Production_tonnes  Yield_hg_per_ha
# 0                2.0               10.0          50000.0
# 1             1100.0            16000.0         145455.0
# 2            40000.0           400000.0         100000.0
# 3            12666.0            13513.0          10669.0
# 4           115000.0            55000.0           4783.0
# 5                NaN            39572.0              NaN
# 6            10000.0             3000.0           3000.0
# 7            55000.0           420000.0          76364.0
# 8             2300.0             3000.0          13043.0
# 9             3200.0             2500.0           7813.0

# %%
# Visualizing the data to check on skewness
import matplotlib.pyplot as plt
cols = ["Area_Harvested_ha", "Production_tonnes", "Yield_hg_per_ha"]

for col in cols:
    plt.figure()
    plt.hist(Kenya_Crops[col].dropna(), bins=30)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
Kenya_Crops[cols].skew()
# Out:
# Area_Harvested_ha    6.258168
# Production_tonnes    5.570305
# Yield_hg_per_ha      4.459131
# dtype: float64

# %% [markdown]
#     The are all right skewed meaning median is safer

# %%
# Checking on missing percentage
Kenya_Crops.isna().mean() * 100
# Out:
# Year                 0.000000
# Item                 0.000000
# Item Code (CPC)      0.000000
# Area_Harvested_ha    7.681793
# Production_tonnes    0.000000
# Yield_hg_per_ha      9.322034
# dtype: float64

# %%
# Filling using median
Kenya_Crops['Area_Harvested_ha'].fillna(Kenya_Crops['Area_Harvested_ha'].median(), inplace=True)
Kenya_Crops['Yield_hg_per_ha'].fillna(Kenya_Crops['Yield_hg_per_ha'].median(), inplace=True)
# Out:
# C:\Users\Sheilla Macharia\AppData\Local\Temp\ipykernel_18184\1978724881.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Kenya_Crops['Area_Harvested_ha'].fillna(Kenya_Crops['Area_Harvested_ha'].median(), inplace=True)
# C:\Users\Sheilla Macharia\AppData\Local\Temp\ipykernel_18184\1978724881.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Kenya_Crops['Yield_hg_per_ha'].fillna(Kenya_Crops['Yield_hg_per_ha'].median(), inplace=True)

# %%
Kenya_Crops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3658 entries, 0 to 3657
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               3658 non-null   int64
#  1   Item               3658 non-null   object
#  2   Item Code (CPC)    3658 non-null   float64
#  3   Area_Harvested_ha  3658 non-null   float64
#  4   Production_tonnes  3658 non-null   float64
#  5   Yield_hg_per_ha    3658 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 171.6+ KB

# %% [markdown]
# ## **Merging the datasets**

# %% [markdown]
#     First merging will be between the kenya crops csv and the region yield csv using the crops.
#     The 6 crops we settled on
#         1. Maize
#         2. Wheat
#         3. Tea
#         4. Sugarcane
#         5. Rice
#         6. Sorghum

# %%
Kenya_Crops.head(10)
# Out:
#    Year                                               Item  Item Code (CPC)  \
# 0  1961                                           Apricots          1343.00
# 1  1961                                           Avocados          1311.00
# 2  1961                                            Bananas          1312.00
# 3  1961                                             Barley           115.00
# 4  1961                                         Beans, dry          1701.00
# 5  1961                             Beer of barley, malted         24310.01
# 6  1961                              Cashew nuts, in shell          1372.00
# 7  1961                                     Cassava, fresh          1520.01
# 8  1961                                   Castor oil seeds          1447.00
# 9  1961  Chillies and peppers, dry (Capsicum spp., Pime...          1652.00
#
#    Area_Harvested_ha  Production_tonnes  Yield_hg_per_ha
# 0                2.0               10.0          50000.0
# 1             1100.0            16000.0         145455.0
# 2            40000.0           400000.0         100000.0
# 3            12666.0            13513.0          10669.0
# 4           115000.0            55000.0           4783.0
# 5             5382.0            39572.0          38235.0
# 6            10000.0             3000.0           3000.0
# 7            55000.0           420000.0          76364.0
# 8             2300.0             3000.0          13043.0
# 9             3200.0             2500.0           7813.0

# %%
Region_Yield.head(10)
# Out:
#    Unnamed: 0        fnid country country_code  admin_1 admin_2     name  \
# 0           0  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 1           1  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 2           2  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 3           3  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 4           4  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 5           5  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 6           6  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 7           7  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 8           8  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
# 9           9  KE2013A101   Kenya           KE  Mombasa    none  Mombasa
#
#               product season_name  planting_year  planting_month  \
# 0                Kale      Annual           2022               1
# 1          Watermelon      Annual           2022               1
# 2              Banana      Annual           2012               1
# 3              Banana      Annual           2013               1
# 4              Banana      Annual           2022               1
# 5  Coconut (in shell)      Annual           2012               1
# 6  Coconut (in shell)      Annual           2013               1
# 7  Coconut (in shell)      Annual           2014               1
# 8  Coconut (in shell)      Annual           2015               1
# 9  Coconut (in shell)      Annual           2016               1
#
#    harvest_year  harvest_month crop_production_system indicator   value
# 0          2022             12               All (PS)      area    21.0
# 1          2022             12               All (PS)      area    26.0
# 2          2012             12               All (PS)      area   125.1
# 3          2013             12               All (PS)      area   121.5
# 4          2022             12               All (PS)      area    39.0
# 5          2012             12               All (PS)      area  6165.0
# 6          2013             12               All (PS)      area  6165.0
# 7          2014             12               All (PS)      area   100.0
# 8          2015             12               All (PS)      area   159.0
# 9          2016             12               All (PS)      area   168.0

# %%
# First change the item column to Product to match with the oher dataset
Kenya_Crops.rename(columns={'Item' : 'product'}, inplace=True)
Kenya_Crops.head()
# Out:
#    Year     product  Item Code (CPC)  Area_Harvested_ha  Production_tonnes  \
# 0  1961    Apricots           1343.0                2.0               10.0
# 1  1961    Avocados           1311.0             1100.0            16000.0
# 2  1961     Bananas           1312.0            40000.0           400000.0
# 3  1961      Barley            115.0            12666.0            13513.0
# 4  1961  Beans, dry           1701.0           115000.0            55000.0
#
#    Yield_hg_per_ha
# 0          50000.0
# 1         145455.0
# 2         100000.0
# 3          10669.0
# 4           4783.0

# %%
# Next is to rename the products in the kenya crops csv so that they align with the crops in the region yeild data
Kenya_Crops['product'] = Kenya_Crops['product'].replace({
    'Maize (corn)': 'Maize',
    'Tea leaves' : 'Tea',
    'Sugar cane' : 'Sugarcane'})

Crops_Item2 = Kenya_Crops['product'].value_counts().index.sort_values(ascending=True)
Crops_Item2
# Out:
# Index(['Apples', 'Apricots', 'Artichokes', 'Asparagus', 'Avocados', 'Bananas',
#        'Barley', 'Beans, dry', 'Beer of barley, malted',
#        'Broad beans and horse beans, green', 'Cabbages', 'Carrots and turnips',
#        'Cashew nuts, in shell', 'Cassava, fresh', 'Castor oil seeds',
#        'Chestnuts, in shell', 'Chick peas, dry',
#        'Chillies and peppers, dry (Capsicum spp., Pimenta spp.), raw',
#        'Chillies and peppers, green (Capsicum spp. and Pimenta spp.)',
#        'Cloves (whole stems), raw', 'Coconuts, in shell', 'Coffee, green',
#        'Cotton lint, ginned', 'Cotton seed', 'Cottonseed oil', 'Cow peas, dry',
#        'Cucumbers and gherkins', 'Dates', 'Ginger, raw', 'Green garlic',
#        'Green tea (not fermented), black tea (fermented) and partly fermented tea',
#        'Groundnuts, excluding shelled',
#        'Leeks and other alliaceous vegetables', 'Lemons and limes',
#        'Lentils, dry', 'Lettuce and chicory', 'Linseed', 'Maize',
#        'Mangoes, guavas and mangosteens', 'Millet', 'Mushrooms and truffles',
#        'Nutmeg, mace, cardamoms, raw', 'Oats',
#        'Onions and shallots, dry (excluding dehydrated)', 'Oranges', 'Papayas',
#        'Peaches and nectarines', 'Pears', 'Peas, green',
#        'Pepper (Piper spp.), raw', 'Pigeon peas, dry', 'Pineapples',
#        'Plantains and cooking bananas', 'Plums and sloes',
#        'Pomelos and grapefruits', 'Potatoes', 'Pyrethrum, dried flowers',
#        'Rice', 'Seed cotton, unginned', 'Sesame seed', 'Sorghum', 'Soya beans',
#        'Spinach', 'Strawberries', 'Sugarcane', 'Sunflower seed',
#        'Sweet potatoes', 'Tangerines, mandarins, clementines', 'Tea',
#        'Tomatoes', 'Unmanufactured tobacco', 'Vanilla, raw', 'Watermelons',
#        'Wheat', 'Yams'],
#       dtype='object', name='product')

# %%
Region_Yield['indicator'].unique()
# Out:
# array(['area', 'production', 'yield'], dtype=object)

# %%
YEARS = range(2000, 2022)
CROPS = ['Maize', 'Wheat', 'Tea', 'Sugarcane', 'Rice', 'Sorghum']

# %%
base = Region_Yield[
    (Region_Yield['planting_year'].between(2000, 2021)) &
    (Region_Yield['harvest_year'] == Region_Yield['planting_year']) &
    (Region_Yield['product'].isin(CROPS))
].copy()

base.rename(columns={
    'product':'Item',
    'admin_1':'Region',
}, inplace=True)

base['Year'] = base['planting_year']

# %%
base_wide = (
    base
    .pivot_table(
        index=['Region','Item','Year', 'season_name'],
        columns='indicator',
        values='value',
        aggfunc='sum'
    )
    .reset_index()
)
base_wide.head()
# Out:
# indicator   Region   Item  Year season_name          area    production  \
# 0          Baringo  Maize  2000      Annual  20500.000000  47997.000000
# 1          Baringo  Maize  2000        Long   2550.000000   1170.000000
# 2          Baringo  Maize  2001      Annual  19650.000000  27614.000000
# 3          Baringo  Maize  2001        Long  10400.000000  22446.000000
# 4          Baringo  Maize  2002      Annual  18151.666508  26385.076714
#
# indicator     yield
# 0          2.341317
# 1          0.458824
# 2          1.405293
# 3          2.158269
# 4          1.453590

# %%
base_wide.head(20)
# Out:
# indicator   Region   Item  Year season_name          area    production  \
# 0          Baringo  Maize  2000      Annual  20500.000000  47997.000000
# 1          Baringo  Maize  2000        Long   2550.000000   1170.000000
# 2          Baringo  Maize  2001      Annual  19650.000000  27614.000000
# 3          Baringo  Maize  2001        Long  10400.000000  22446.000000
# 4          Baringo  Maize  2002      Annual  18151.666508  26385.076714
# 5          Baringo  Maize  2003      Annual  23996.000000  31926.000000
# 6          Baringo  Maize  2004      Annual  13795.000000  54904.100000
# 7          Baringo  Maize  2005      Annual  20550.000000  46242.000000
# 8          Baringo  Maize  2012      Annual  29117.000000  55805.040000
# 9          Baringo  Maize  2013      Annual  34960.000000  34959.960000
# 10         Baringo  Maize  2014      Annual  44159.000000  83313.000000
# 11         Baringo  Maize  2015      Annual  33163.000000  72495.000000
# 12         Baringo  Maize  2015        Long  38301.000000  87802.000000
# 13         Baringo  Maize  2016      Annual  33308.000000  49840.500000
# 14         Baringo  Maize  2016        Long  36480.000000  83200.770000
# 15         Baringo  Maize  2017      Annual  37658.000000  58475.600000
# 16         Baringo  Maize  2017        Long  34597.000000  49882.050000
# 17         Baringo  Maize  2018      Annual  45171.000000  70810.300000
# 18         Baringo  Maize  2018        Long  45122.000000  77739.030000
# 19         Baringo  Maize  2019      Annual  47437.000000  68374.390000
#
# indicator     yield
# 0          2.341317
# 1          0.458824
# 2          1.405293
# 3          2.158269
# 4          1.453590
# 5          1.330472
# 6          3.980000
# 7          2.250219
# 8          1.916579
# 9          0.999999
# 10         1.886660
# 11         2.186021
# 12         2.292421
# 13         1.496352
# 14         2.280723
# 15         1.552807
# 16         1.441803
# 17         1.567605
# 18         1.722863
# 19         1.441373

# %%
base_wide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2204 entries, 0 to 2203
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Region       2204 non-null   object
#  1   Item         2204 non-null   object
#  2   Year         2204 non-null   int64
#  3   season_name  2204 non-null   object
#  4   area         2204 non-null   float64
#  5   production   2165 non-null   float64
#  6   yield        2165 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 120.7+ KB

# %%
Region_Yield['season_name'].unique()
# Out:
# array(['Annual', 'Long', 'Short'], dtype=object)

# %%
base_wide['yield_hg_per_ha'] = (
    base_wide['production'] * 10000
) / base_wide['area']

# %%
base_wide.head(20)
# Out:
# indicator   Region   Item  Year season_name          area    production  \
# 0          Baringo  Maize  2000      Annual  20500.000000  47997.000000
# 1          Baringo  Maize  2000        Long   2550.000000   1170.000000
# 2          Baringo  Maize  2001      Annual  19650.000000  27614.000000
# 3          Baringo  Maize  2001        Long  10400.000000  22446.000000
# 4          Baringo  Maize  2002      Annual  18151.666508  26385.076714
# 5          Baringo  Maize  2003      Annual  23996.000000  31926.000000
# 6          Baringo  Maize  2004      Annual  13795.000000  54904.100000
# 7          Baringo  Maize  2005      Annual  20550.000000  46242.000000
# 8          Baringo  Maize  2012      Annual  29117.000000  55805.040000
# 9          Baringo  Maize  2013      Annual  34960.000000  34959.960000
# 10         Baringo  Maize  2014      Annual  44159.000000  83313.000000
# 11         Baringo  Maize  2015      Annual  33163.000000  72495.000000
# 12         Baringo  Maize  2015        Long  38301.000000  87802.000000
# 13         Baringo  Maize  2016      Annual  33308.000000  49840.500000
# 14         Baringo  Maize  2016        Long  36480.000000  83200.770000
# 15         Baringo  Maize  2017      Annual  37658.000000  58475.600000
# 16         Baringo  Maize  2017        Long  34597.000000  49882.050000
# 17         Baringo  Maize  2018      Annual  45171.000000  70810.300000
# 18         Baringo  Maize  2018        Long  45122.000000  77739.030000
# 19         Baringo  Maize  2019      Annual  47437.000000  68374.390000
#
# indicator     yield  yield_hg_per_ha
# 0          2.341317     23413.170732
# 1          0.458824      4588.235294
# 2          1.405293     14052.926209
# 3          2.158269     21582.692308
# 4          1.453590     14535.897683
# 5          1.330472     13304.717453
# 6          3.980000     39800.000000
# 7          2.250219     22502.189781
# 8          1.916579     19165.793179
# 9          0.999999      9999.988558
# 10         1.886660     18866.595711
# 11         2.186021     21860.205651
# 12         2.292421     22924.205634
# 13         1.496352     14963.522277
# 14         2.280723     22807.228618
# 15         1.552807     15528.068405
# 16         1.441803     14418.027575
# 17         1.567605     15676.053220
# 18         1.722863     17228.631266
# 19         1.441373     14413.725573

# %%
# remove ' Average' from Month Average
Temp_df['month_short'] = Temp_df['Month Average'].str.replace(' Average','', regex=False)
Rainfall_df['month_short'] = Rainfall_df['Month Average'].str.replace(' Average','', regex=False)

# map short month names to numbers
month_map = {'Jan':1,'Feb':2,'Mar':3,'Apr':4,'May':5,'Jun':6,
             'Jul':7,'Aug':8,'Sep':9,'Oct':10,'Nov':11,'Dec':12}

Temp_df['month'] = Temp_df['month_short'].map(month_map)
Rainfall_df['month'] = Rainfall_df['month_short'].map(month_map)

# verify mapping worked
print(Temp_df[['Month Average','month_short','month']].head(12))
print(Rainfall_df[['Month Average','month_short','month']].head(12))
# Out:
#    Month Average month_short  month
# 0    Jan Average         Jan      1
# 1    Feb Average         Feb      2
# 2    Mar Average         Mar      3
# 3    Apr Average         Apr      4
# 4    May Average         May      5
# 5    Jun Average         Jun      6
# 6    Jul Average         Jul      7
# 7    Aug Average         Aug      8
# 8    Sep Average         Sep      9
# 9    Oct Average         Oct     10
# 10   Nov Average         Nov     11
# 11   Dec Average         Dec     12
#    Month Average month_short  month
# 0    Jan Average         Jan      1
# 1    Feb Average         Feb      2
# 2    Mar Average         Mar      3
# 3    Apr Average         Apr      4
# 4    May Average         May      5
# 5    Jun Average         Jun      6
# 6    Jul Average         Jul      7
# 7    Aug Average         Aug      8
# 8    Sep Average         Sep      9
# 9    Oct Average         Oct     10
# 10   Nov Average         Nov     11
# 11   Dec Average         Dec     12

# %%
#Define a safe seasonal aggregation function
def seasonal_climate(temp_df, rain_df, month, label):
    t = temp_df[temp_df['month'].isin(month)].groupby('Year', as_index=False)['Temperature - (Celsius)'].mean()
    r = rain_df[rain_df['month'].isin(month)].groupby('Year', as_index=False)['Rainfall - (MM)'].sum()
    df = pd.merge(t, r, on='Year', how='outer')  # use outer to preserve all years
    df['season_name'] = label
    return df

# Create seasonal climate
long_clim = seasonal_climate(Temp_df, Rainfall_df, [3,4,5,6,7,8], 'Long')
short_clim = seasonal_climate(Temp_df, Rainfall_df, [10,11,12], 'Short')
annual_clim = seasonal_climate(Temp_df, Rainfall_df, list(range(1,13)), 'Annual')

# Concatenate all seasons
climate = pd.concat([long_clim, short_clim, annual_clim], ignore_index=True)

# Check
print(climate['season_name'].unique())
print(climate.head())
# Out:
# ['Long' 'Short' 'Annual']
#    Year  Temperature - (Celsius)  Rainfall - (MM) season_name
# 0  1991                24.407967         371.8503        Long
# 1  1992                24.515367         310.7993        Long
# 2  1993                24.485000         299.3617        Long
# 3  1994                24.357817         351.3330        Long
# 4  1995                24.687967         369.5545        Long

# %%
final = base_wide.merge(
    climate,
    on=['Year','season_name'],
    how='left'
)

# %%
final.head(20)
# Out:
#      Region   Item  Year season_name          area    production     yield  \
# 0   Baringo  Maize  2000      Annual  20500.000000  47997.000000  2.341317
# 1   Baringo  Maize  2000        Long   2550.000000   1170.000000  0.458824
# 2   Baringo  Maize  2001      Annual  19650.000000  27614.000000  1.405293
# 3   Baringo  Maize  2001        Long  10400.000000  22446.000000  2.158269
# 4   Baringo  Maize  2002      Annual  18151.666508  26385.076714  1.453590
# 5   Baringo  Maize  2003      Annual  23996.000000  31926.000000  1.330472
# 6   Baringo  Maize  2004      Annual  13795.000000  54904.100000  3.980000
# 7   Baringo  Maize  2005      Annual  20550.000000  46242.000000  2.250219
# 8   Baringo  Maize  2012      Annual  29117.000000  55805.040000  1.916579
# 9   Baringo  Maize  2013      Annual  34960.000000  34959.960000  0.999999
# 10  Baringo  Maize  2014      Annual  44159.000000  83313.000000  1.886660
# 11  Baringo  Maize  2015      Annual  33163.000000  72495.000000  2.186021
# 12  Baringo  Maize  2015        Long  38301.000000  87802.000000  2.292421
# 13  Baringo  Maize  2016      Annual  33308.000000  49840.500000  1.496352
# 14  Baringo  Maize  2016        Long  36480.000000  83200.770000  2.280723
# 15  Baringo  Maize  2017      Annual  37658.000000  58475.600000  1.552807
# 16  Baringo  Maize  2017        Long  34597.000000  49882.050000  1.441803
# 17  Baringo  Maize  2018      Annual  45171.000000  70810.300000  1.567605
# 18  Baringo  Maize  2018        Long  45122.000000  77739.030000  1.722863
# 19  Baringo  Maize  2019      Annual  47437.000000  68374.390000  1.441373
#
#     yield_hg_per_ha  Temperature - (Celsius)  Rainfall - (MM)
# 0      23413.170732                24.904750        448.51506
# 1       4588.235294                24.955150        243.42790
# 2      14052.926209                25.095758        622.51956
# 3      21582.692308                24.650217        320.87500
# 4      14535.897683                25.478067        780.85290
# 5      13304.717453                25.454358        616.82425
# 6      39800.000000                25.312442        552.58700
# 7      22502.189781                25.329817        434.60670
# 8      19165.793179                25.245150        756.21300
# 9       9999.988558                25.182175        769.69140
# 10     18866.595711                25.411450        614.67850
# 11     21860.205651                25.537633        771.97570
# 12     22924.205634                25.183083        395.94930
# 13     14963.522277                25.756608        715.20220
# 14     22807.228618                25.444700        362.85080
# 15     15528.068405                      NaN              NaN
# 16     14418.027575                      NaN              NaN
# 17     15676.053220                      NaN              NaN
# 18     17228.631266                      NaN              NaN
# 19     14413.725573                      NaN              NaN

# %%
climate['season_name'].unique()
# Out:
# array(['Long', 'Short', 'Annual'], dtype=object)

# %%
# Only use existing climate data
climate_existing = climate[climate['Year'] <= 2016]

# Compute mean temperature and rainfall per season
seasonal_means = (
    climate_existing
    .groupby('season_name')[['Temperature - (Celsius)','Rainfall - (MM)']]
    .mean()
    .reset_index()
)

print(seasonal_means)
# Out:
#   season_name  Temperature - (Celsius)  Rainfall - (MM)
# 0      Annual                25.118588       657.609658
# 1        Long                24.901159       347.449854
# 2       Short                25.184171       224.883414

# %%
years_missing = list(range(2017, 2023))
seasons = ['Annual','Long','Short']

# Create all combinations
import itertools
rows = list(itertools.product(years_missing, seasons))
climate_missing = pd.DataFrame(rows, columns=['Year','season_name'])

# %%
climate_missing = climate_missing.merge(seasonal_means, on='season_name', how='left')

# %%
climate_full = pd.concat([climate_existing, climate_missing], ignore_index=True)

# sort
climate_full = climate_full.sort_values(['Year','season_name']).reset_index(drop=True)

# %%
final = base_wide.merge(climate_full, on=['Year','season_name'], how='left')

# %%
final.head(20)
# Out:
#      Region   Item  Year season_name          area    production     yield  \
# 0   Baringo  Maize  2000      Annual  20500.000000  47997.000000  2.341317
# 1   Baringo  Maize  2000        Long   2550.000000   1170.000000  0.458824
# 2   Baringo  Maize  2001      Annual  19650.000000  27614.000000  1.405293
# 3   Baringo  Maize  2001        Long  10400.000000  22446.000000  2.158269
# 4   Baringo  Maize  2002      Annual  18151.666508  26385.076714  1.453590
# 5   Baringo  Maize  2003      Annual  23996.000000  31926.000000  1.330472
# 6   Baringo  Maize  2004      Annual  13795.000000  54904.100000  3.980000
# 7   Baringo  Maize  2005      Annual  20550.000000  46242.000000  2.250219
# 8   Baringo  Maize  2012      Annual  29117.000000  55805.040000  1.916579
# 9   Baringo  Maize  2013      Annual  34960.000000  34959.960000  0.999999
# 10  Baringo  Maize  2014      Annual  44159.000000  83313.000000  1.886660
# 11  Baringo  Maize  2015      Annual  33163.000000  72495.000000  2.186021
# 12  Baringo  Maize  2015        Long  38301.000000  87802.000000  2.292421
# 13  Baringo  Maize  2016      Annual  33308.000000  49840.500000  1.496352
# 14  Baringo  Maize  2016        Long  36480.000000  83200.770000  2.280723
# 15  Baringo  Maize  2017      Annual  37658.000000  58475.600000  1.552807
# 16  Baringo  Maize  2017        Long  34597.000000  49882.050000  1.441803
# 17  Baringo  Maize  2018      Annual  45171.000000  70810.300000  1.567605
# 18  Baringo  Maize  2018        Long  45122.000000  77739.030000  1.722863
# 19  Baringo  Maize  2019      Annual  47437.000000  68374.390000  1.441373
#
#     yield_hg_per_ha  Temperature - (Celsius)  Rainfall - (MM)
# 0      23413.170732                24.904750       448.515060
# 1       4588.235294                24.955150       243.427900
# 2      14052.926209                25.095758       622.519560
# 3      21582.692308                24.650217       320.875000
# 4      14535.897683                25.478067       780.852900
# 5      13304.717453                25.454358       616.824250
# 6      39800.000000                25.312442       552.587000
# 7      22502.189781                25.329817       434.606700
# 8      19165.793179                25.245150       756.213000
# 9       9999.988558                25.182175       769.691400
# 10     18866.595711                25.411450       614.678500
# 11     21860.205651                25.537633       771.975700
# 12     22924.205634                25.183083       395.949300
# 13     14963.522277                25.756608       715.202200
# 14     22807.228618                25.444700       362.850800
# 15     15528.068405                25.118588       657.609658
# 16     14418.027575                24.901159       347.449854
# 17     15676.053220                25.118588       657.609658
# 18     17228.631266                24.901159       347.449854
# 19     14413.725573                25.118588       657.609658

# %%
#filter for the right element
pest_area = Pesticides_df[Pesticides_df['Element']=='Use per area of cropland'][['Year','Value']]

# remove duplicate years (take mean if multiple)
pest_area = pest_area.groupby('Year', as_index=False).mean()

#reindex and interpolate missing years
years_full = range(2000, 2023)  # make sure 2022 is included
pest_area = pest_area.set_index('Year').reindex(years_full).interpolate(method='linear').reset_index()

# rename for clarity
pest_area.rename(columns={'Value':'pesticides_kg_per_ha'}, inplace=True)

# Merge with base dataset
final2 = final.merge(pest_area, on='Year', how='left')

# Add tiny regional variation to break identical numbers
import numpy as np
np.random.seed(42)  # reproducible
final2['pesticides_kg_per_ha'] = final2['pesticides_kg_per_ha'] * (1 + np.random.uniform(-0.05,0.05, size=len(final)))

# %%
final2.head(20)
# Out:
# 1278    NaN              NaN                25.118588       657.609658
# 1301    NaN              NaN                25.118588       657.609658
# 1384    NaN              NaN                25.183083       395.949300
# 1491    NaN              NaN                25.118588       657.609658
# 1551    NaN              NaN                25.118588       657.609658
# 1650    NaN              NaN                25.756608       715.202200
# 1746    NaN              NaN                25.454358       616.824250
# 1808    NaN              NaN                25.118588       657.609658
# 1846    NaN              NaN                25.183083       395.949300
# 1985    NaN              NaN                25.118588       657.609658
# 2086    NaN              NaN                25.118588       657.609658
# 2128    NaN              NaN                25.118588       657.609658
# 2140    NaN              NaN                25.118588       657.609658
# 2143    NaN              NaN                24.955150       243.427900
#
#       pesticides_hg_per_ha
# 147              44.828963
# 209              43.296801
# 250              43.002741
# 331              44.783526
# 347              41.495512
# 404              44.010474
# 406              35.591667
# 421              45.208556
# 425              43.874058
# 433              41.738167
# 434              42.350501
# 467              45.074554
# 525              44.676649
# 580              44.633815
# 775              43.247993
# 840              42.634794
# 842              34.831672
# 844              34.411746
# 869              45.411535
# 926              43.780239
# 1020             36.700959
# 1120             37.389556
# 1139             44.061258
# 1147             44.160998
# 1148             45.737421
# 1278             43.214730
# 1301             46.771927
# 1384             44.153542
# 1491             44.248910
# 1551             44.351346
# 1650             42.138634
# 1746             37.145958
# 1808             43.356414
# 1846             41.826758
# 1985             42.937340
# 2086             43.048810
# 2128             45.582080
# 2140             45.050788
# 2143             35.322273

# %%
# Fill missing production with mean per Region × Item × season_name
final2['production'] = final2.groupby(['Region','Item','season_name'])['production'].transform(
    lambda x: x.fillna(x.mean())
)

# %%
final2[final2['production'].isna()]
# Out:
# Empty DataFrame
# Columns: [Region, Item, Year, season_name, area, production, yield, yield_hg_per_ha, Temperature - (Celsius), Rainfall - (MM), pesticides_hg_per_ha]
# Index: []

# %%
final2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2204 entries, 0 to 2203
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Region                   2204 non-null   object
#  1   Item                     2204 non-null   object
#  2   Year                     2204 non-null   int64
#  3   season_name              2204 non-null   object
#  4   area                     2204 non-null   float64
#  5   production               2204 non-null   float64
#  6   yield                    2165 non-null   float64
#  7   yield_hg_per_ha          2165 non-null   float64
#  8   Temperature - (Celsius)  2204 non-null   float64
#  9   Rainfall - (MM)          2204 non-null   float64
#  10  pesticides_hg_per_ha     2204 non-null   float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 189.5+ KB

# %%
final2['yield'] = final2['production'] / final2['area']
final2['yield_hg_per_ha'] = final2['yield'] * 10000

# %%
final2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2204 entries, 0 to 2203
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Region                   2204 non-null   object
#  1   Item                     2204 non-null   object
#  2   Year                     2204 non-null   int64
#  3   season_name              2204 non-null   object
#  4   area                     2204 non-null   float64
#  5   production               2204 non-null   float64
#  6   yield                    2204 non-null   float64
#  7   yield_hg_per_ha          2204 non-null   float64
#  8   Temperature - (Celsius)  2204 non-null   float64
#  9   Rainfall - (MM)          2204 non-null   float64
#  10  pesticides_hg_per_ha     2204 non-null   float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 189.5+ KB

# %%
#final2.to_csv('clean_data.csv', index=False)

# %%
data = pd.read_csv('../data/clean_data.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2204 entries, 0 to 2203
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   